# %% [markdown]
# ## Model Training with Machine Learning <a name='training'></a>

# %%
import pandas as pd
from pyspark.sql import functions as F

# %%
df_model = df[['Job ID', 'Business Title', 'Job Description', 'Minimum Qual Requirements', 'Preferred Skills', 'Work Location']]

# %%
df1_model = df_model.withColumn('Merged Columns', F.concat(F.col('Business Title'), F.lit(' '), F.col('Job Description'), F.lit(' '), F.col('Minimum Qual Requirements'), F.lit(' '), F.col('Preferred Skills')))
df1_model.show()
# Out:
# +------+--------------------+--------------------+-------------------------+--------------------+--------------------+--------------------+
# |Job ID|      Business Title|     Job Description|Minimum Qual Requirements|    Preferred Skills|       Work Location|      Merged Columns|
# +------+--------------------+--------------------+-------------------------+--------------------+--------------------+--------------------+
# | 87990|     Account Manager|Division of Econo...|     "1.	A baccalaurea...| all candidates m...| 110 William St. N Y|Account Manager D...|
# | 97899|EXECUTIVE DIRECTO...|The New York City...|     "1. A baccalaurea...|                null| 110 William St. N Y|                null|
# |132292|Maintenance Worke...|Under direct supe...|     "1. Three years o...|          mechanical|Heating Mgt-Opera...|Maintenance Worke...|
# |132292|Maintenance Worke...|Under direct supe...|     "1. Three years o...|          mechanical|Heating Mgt-Opera...|Maintenance Worke...|
# |133921|   Temporary Painter|Responsibilities ...|     1. Five years of ...|                null|DMP-Contract & An...|                null|
# |133921|   Temporary Painter|Responsibilities ...|     1. Five years of ...|                null|DMP-Contract & An...|                null|
# |137433|    Contract Analyst|** OPEN TO PERMAN...|     "1. A baccalaurea...| individuals must...|   42-09 28th Street|Contract Analyst ...|
# |138531|   Associate Chemist|Working in the Di...|     Qualification Req...|In order to apply...|96-05 Horace Hard...|Associate Chemist...|
# |151131|Cost Estimating M...|Reporting to the ...|     "1. A master's de...| including the 18...|CP Cap Plan-Techn...|Cost Estimating M...|
# |151937|Assistant Project...|The Assistant Pro...|     "One year of full...| candidates must ...|Office for Exec P...|Assistant Project...|
# |151937|Assistant Project...|The Assistant Pro...|     "One year of full...| candidates must ...|Office for Exec P...|Assistant Project...|
# |152738|      Office Manager|Performs essentia...|     Qualification Req...|Experience with L...|100 Church St., N.Y.|Office Manager Pe...|
# |160910|Deputy Director, ...|DoITT provides fo...|     "1. A baccalaurea...| 18 months of whi...|75 Park Place New...|Deputy Director, ...|
# |167179|CERTIFIED IT ADMI...|Oversees the desi...|     "1. A baccalaurea...| all candidates m...|335 Adams Street,...|CERTIFIED IT ADMI...|
# |167179|CERTIFIED IT ADMI...|Oversees the desi...|     "1. A baccalaurea...| all candidates m...|335 Adams Street,...|CERTIFIED IT ADMI...|
# |170989|COLLEGE AIDE - CL...|The Office of Col...|     For Assignment Le...|1.	Excellent inte...|     100 Gold Street|COLLEGE AIDE - CL...|
# |170989|COLLEGE AIDE - CL...|The Office of Col...|     For Assignment Le...|1.	Excellent inte...|     100 Gold Street|COLLEGE AIDE - CL...|
# |171040|Clerical Associat...|** OPEN TO PERMAN...|     Qualification Req...|-	Good writing an...|   42-09 28th Street|Clerical Associat...|
# |171944|Deputy Director, ...|DoITT provides fo...|     "Qualification Re...| acquired with th...|75 Park Place New...|Deputy Director, ...|
# |172053|311 Call Center M...|DoITT provides fo...|     "1. A baccalaurea...| 18 months of whi...|      59 Maiden Lane|311 Call Center M...|
# +------+--------------------+--------------------+-------------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# converting into pandas due to complexity of defining a new desired column in spark
dfp_model = df1_model.toPandas()
dfp_model.head()
# Out:
#    Job ID                                     Business Title  \
# 0   87990                                    Account Manager
# 1   97899           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  132292  Maintenance Worker - Technical Services-Heatin...
# 3  132292  Maintenance Worker - Technical Services-Heatin...
# 4  133921                                  Temporary Painter
#
#                                      Job Description  \
# 0  Division of Economic & Financial Opportunity (...
# 1  The New York City Department of Small Business...
# 2  Under direct supervision, assist in the routin...
# 3  Under direct supervision, assist in the routin...
# 4  Responsibilities of selected candidates will i...
#
#                            Minimum Qual Requirements  \
# 0  "1.\tA baccalaureate degree from an accredited...
# 1  "1. A baccalaureate degree from an accredited ...
# 2  "1. Three years of full-time satisfactory expe...
# 3  "1. Three years of full-time satisfactory expe...
# 4  1. Five years of full-time satisfactory experi...
#
#                                     Preferred Skills  \
# 0   all candidates must have at least one year of...
# 1                                               None
# 2                                         mechanical
# 3                                         mechanical
# 4                                               None
#
#                   Work Location  \
# 0           110 William St. N Y
# 1           110 William St. N Y
# 2        Heating Mgt-Operations
# 3        Heating Mgt-Operations
# 4  DMP-Contract & Analysis Unit
#
#                                       Merged Columns
# 0  Account Manager Division of Economic & Financi...
# 1                                               None
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                               None

# %%
# coverting data type into string from object
dfp_model['Merged Columns'] = dfp_model['Merged Columns'].astype(str)

# %%
# converting into Title case the required column values
dfp_model['Business Title'] = dfp_model['Business Title'].str.title()
dfp_model['Merged Columns'] = dfp_model['Merged Columns'].str.title()
dfp_model.head()
# Out:
#    Job ID                                     Business Title  \
# 0   87990                                    Account Manager
# 1   97899           Executive Director, Business Development
# 2  132292  Maintenance Worker - Technical Services-Heatin...
# 3  132292  Maintenance Worker - Technical Services-Heatin...
# 4  133921                                  Temporary Painter
#
#                                      Job Description  \
# 0  Division of Economic & Financial Opportunity (...
# 1  The New York City Department of Small Business...
# 2  Under direct supervision, assist in the routin...
# 3  Under direct supervision, assist in the routin...
# 4  Responsibilities of selected candidates will i...
#
#                            Minimum Qual Requirements  \
# 0  "1.\tA baccalaureate degree from an accredited...
# 1  "1. A baccalaureate degree from an accredited ...
# 2  "1. Three years of full-time satisfactory expe...
# 3  "1. Three years of full-time satisfactory expe...
# 4  1. Five years of full-time satisfactory experi...
#
#                                     Preferred Skills  \
# 0   all candidates must have at least one year of...
# 1                                               None
# 2                                         mechanical
# 3                                         mechanical
# 4                                               None
#
#                   Work Location  \
# 0           110 William St. N Y
# 1           110 William St. N Y
# 2        Heating Mgt-Operations
# 3        Heating Mgt-Operations
# 4  DMP-Contract & Analysis Unit
#
#                                       Merged Columns
# 0  Account Manager Division Of Economic & Financi...
# 1                                               None
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                               None

# %%
# !pip install rake-nltk
from rake_nltk import Rake
import nltk

# %%
# Extracting Keywords
# defining new column
dfp_model['Keywords'] = ''

for index, row in dfp_model.iterrows():
    keywords = row['Merged Columns']
    
    # Instantiating Rake, by default it uses english stopwords from NLTK and discards all puntuation characters as well
    r = Rake()
    
    # Extracting words by passing text
    r.extract_keywords_from_text(keywords)
    
    # Getting the dictionary with keywords as keys and their scores as values
    keywords_dict_scores = r.get_word_degrees()
    
    # Assigning the keywords to the new column
    row['Keywords'] = list(keywords_dict_scores.keys())
    
# Dropping the Merged Column, its job's done
dfp_model.drop(columns = ['Merged Columns'], inplace = True)

# %%
dfp_model.drop_duplicates(subset='Business Title', inplace=True)
dfp_model.set_index('Business Title', inplace=True)
print(dfp_model.columns)
dfp_model.head()
# Out:
# Index(['Job ID', 'Job Description', 'Minimum Qual Requirements',
#        'Preferred Skills', 'Work Location', 'Keywords'],
#       dtype='object')
#                                                     Job ID  \
# Business Title
# Account Manager                                      87990
# Executive Director, Business Development             97899
# Maintenance Worker - Technical Services-Heating...  132292
# Temporary Painter                                   133921
# Contract Analyst                                    137433
#
#                                                                                       Job Description  \
# Business Title
# Account Manager                                     Division of Economic & Financial Opportunity (...
# Executive Director, Business Development            The New York City Department of Small Business...
# Maintenance Worker - Technical Services-Heating...  Under direct supervision, assist in the routin...
# Temporary Painter                                   Responsibilities of selected candidates will i...
# Contract Analyst                                    ** OPEN TO PERMANENT PROCUREMENT ANALYSTS ONLY...
#
#                                                                             Minimum Qual Requirements  \
# Business Title
# Account Manager                                     "1.\tA baccalaureate degree from an accredited...
# Executive Director, Business Development            "1. A baccalaureate degree from an accredited ...
# Maintenance Worker - Technical Services-Heating...  "1. Three years of full-time satisfactory expe...
# Temporary Painter                                   1. Five years of full-time satisfactory experi...
# Contract Analyst                                    "1. A baccalaureate degree from an accredited ...
#
#                                                                                      Preferred Skills  \
# Business Title
# Account Manager                                      all candidates must have at least one year of...
# Executive Director, Business Development                                                         None
# Maintenance Worker - Technical Services-Heating...                                         mechanical
# Temporary Painter                                                                                None
# Contract Analyst                                                                individuals must have
#
#                                                                    Work Location  \
# Business Title
# Account Manager                                              110 William St. N Y
# Executive Director, Business Development                     110 William St. N Y
# Maintenance Worker - Technical Services-Heating...        Heating Mgt-Operations
# Temporary Painter                                   DMP-Contract & Analysis Unit
# Contract Analyst                                               42-09 28th Street
#
#                                                                                              Keywords
# Business Title
# Account Manager                                     [baccalaureate, degree, defo, agencies, method...
# Executive Director, Business Development                                                       [none]
# Maintenance Worker - Technical Services-Heating...  [full, routine, maintenance, operation, 00, pm...
# Temporary Painter                                                                              [none]
# Contract Analyst                                    [baccalaureate, degree, full, final, financial...

# %%
dfp1_model = dfp_model[['Job ID', 'Keywords', 'Work Location']]
dfp1_model.head()
# Out:
#                                                     Job ID  \
# Business Title
# Account Manager                                      87990
# Executive Director, Business Development             97899
# Maintenance Worker - Technical Services-Heating...  132292
# Temporary Painter                                   133921
# Contract Analyst                                    137433
#
#                                                                                              Keywords  \
# Business Title
# Account Manager                                     [baccalaureate, degree, defo, agencies, method...
# Executive Director, Business Development                                                       [none]
# Maintenance Worker - Technical Services-Heating...  [full, routine, maintenance, operation, 00, pm...
# Temporary Painter                                                                              [none]
# Contract Analyst                                    [baccalaureate, degree, full, final, financial...
#
#                                                                    Work Location
# Business Title
# Account Manager                                              110 William St. N Y
# Executive Director, Business Development                     110 William St. N Y
# Maintenance Worker - Technical Services-Heating...        Heating Mgt-Operations
# Temporary Painter                                   DMP-Contract & Analysis Unit
# Contract Analyst                                               42-09 28th Street

# %%
dfp1_model['Keywords'] = dfp1_model['Keywords'].apply(', '.join)
dfp1_model.head()
# Out:
#                                                     Job ID  \
# Business Title
# Account Manager                                      87990
# Executive Director, Business Development             97899
# Maintenance Worker - Technical Services-Heating...  132292
# Temporary Painter                                   133921
# Contract Analyst                                    137433
#
#                                                                                              Keywords  \
# Business Title
# Account Manager                                     baccalaureate, degree, defo, agencies, methods...
# Executive Director, Business Development                                                         none
# Maintenance Worker - Technical Services-Heating...  full, routine, maintenance, operation, 00, pm,...
# Temporary Painter                                                                                none
# Contract Analyst                                    baccalaureate, degree, full, final, financial,...
#
#                                                                    Work Location
# Business Title
# Account Manager                                              110 William St. N Y
# Executive Director, Business Development                     110 William St. N Y
# Maintenance Worker - Technical Services-Heating...        Heating Mgt-Operations
# Temporary Painter                                   DMP-Contract & Analysis Unit
# Contract Analyst                                               42-09 28th Street

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# training using TfidfVectorizer
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(dfp1_model['Keywords'])

# %%
# generating cosine similarity matrix
csm = cosine_similarity(tfidf_matrix, tfidf_matrix)
csm
# Out:
# array([[1.        , 0.        , 0.00526631, ..., 0.01638283, 0.00998656,
#         0.01008194],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.00526631, 0.        , 1.        , ..., 0.00463767, 0.0078415 ,
#         0.00488791],
#        ...,
#        [0.01638283, 0.        , 0.00463767, ..., 1.        , 0.01652949,
#         0.01280633],
#        [0.00998656, 0.        , 0.0078415 , ..., 0.01652949, 1.        ,
#         0.01108155],
#        [0.01008194, 0.        , 0.00488791, ..., 0.01280633, 0.01108155,
#         1.        ]])

# %%
# recommendation function
# making a business title Series, so they are associated to an ordered numerical list, that will be used in the function to match the indices
indices = pd.Series(dfp1_model.index)

# defining a function that takes business title as input and returns top 15 recommended jobs accordingly
def recommend(title, csm=csm):
    
    # initialization of empty list of recommended jobs
    recommended_jobs = []
    locations = []
    
    # getting the index of the job with matching title
    idx = indices[indices == title].index[0]
    
    # creating a series with descending order of similarity scores
    score_series = pd.Series(csm[idx]).sort_values(ascending=False)
    
    # obtaining the indices of top 10 most similar jobs
    top15_indices = list(score_series.iloc[0:15].index)
    
    # inserting the jobs in the recommendations' list
    for i in top15_indices:
        recommended_jobs.append(list(dfp1_model.index)[i])
        locations.append(list(dfp1_model['Work Location'])[i])
        
    recommendations = pd.DataFrame({'Job Roles': recommended_jobs, 'Location': locations}).style.hide_index()
        
    return recommendations

# %% [markdown]
# ## Output <a name='output'></a>

# %%
# testing the recommendation system
recommend('Account Manager')
# Out:
# <style  type="text/css" >
# </style><table id="T_394b165e_b437_11ea_b29b_302432e0fb9a" ><thead>    <tr>        <th class="col_heading level0 col0" >Job Roles</th>        <th class="col_heading level0 col1" >Location</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow0_col0" class="data row0 col0" >Account Manager</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow0_col1" class="data row0 col1" >110 William St. N Y</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow1_col0" class="data row1 col0" >Project Manager, Pmo</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow1_col1" class="data row1 col1" >110 William St. N Y</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow2_col0" class="data row2 col0" >Minority/Women-Owned Business  Enterp. Liaison</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow2_col1" class="data row2 col1" >4 World Trade Center</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow3_col0" class="data row3 col0" >Director, Customized Training Program</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow3_col1" class="data row3 col1" >110 William St. N Y</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow4_col0" class="data row4 col0" >Project Performance Analyst</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow4_col1" class="data row4 col1" >253 Broadway New York Ny</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow5_col0" class="data row5 col0" >Executive Director, Employer Based Training</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow5_col1" class="data row5 col1" >110 William St. N Y</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow6_col0" class="data row6 col0" >Compliance Manager, Mayor'S Office Of M/Wbe</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow6_col1" class="data row6 col1" >253 Broadway New York Ny</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow7_col0" class="data row7 col0" >Program Manager - Construction Safety Training</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow7_col1" class="data row7 col1" >110 William St. N Y</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow8_col0" class="data row8 col0" >Video Producer</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow8_col1" class="data row8 col1" >253 Broadway New York Ny</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow9_col0" class="data row9 col0" >Program Manager, Candidate Services</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow9_col1" class="data row9 col1" >110 William St. N Y</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow10_col0" class="data row10 col0" >Equal Employment Opportunity & Diversity Coordinator</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow10_col1" class="data row10 col1" >2 Metro Tech</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow11_col0" class="data row11 col0" >Analyst</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow11_col1" class="data row11 col1" >150 William Street, New York N</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow12_col0" class="data row12 col0" >Director Of Contracts</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow12_col1" class="data row12 col1" >1 Centre St., N.Y.</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow13_col0" class="data row13 col0" >Zone Coordinator, Far Rockaway And Jamaica</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow13_col1" class="data row13 col1" >REES - Zone Coordination</td>
#             </tr>
#             <tr>
#                                 <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow14_col0" class="data row14 col0" >Data And Operations Analyst</td>
#                         <td id="T_394b165e_b437_11ea_b29b_302432e0fb9arow14_col1" class="data row14 col1" >110 William St. N Y</td>
#             </tr>
#     </tbody></table>

# %%
# testing keywords
dfp1_model.iloc[dfp1_model.index.get_loc('Data And Operations Analyst')]['Keywords']
# Out:
# 'baccalaureate, degree, program, initiatives, successfully, â, €¢, conduct, policy, needed, methods, duties, press, elected, officials, area, related, 2, new, tools, sensitive, requests, various, audiences, respond, public, execute, best, practice, research, center, executive, office, support, internal, operations, across, qualitative, least, one, year, train, staff, assist, around, common, division, tasks, priorities, project, implementation, performance, indicators, customer, relationship, management, technology, analyst, however, inform, well, candidates, must, policies, "", templates, impact, tracking, community, work, including, working, gather, necessary, information, equivalent, .", especially, described, quality, assurance, needs, carry, documenting, options, budget, presentations, pipeline, development, use, quantitative, centered, activities, york, city, measuring, key, help, develop, institutional, partners, accredited, college, practices, synthesize, complex, ranging, experience, enhancement, 3, six, years, measurement, wide, portfolio, data, analysis, systems, 1, analyses, programs, serving, business, owners, hall, high, school, graduation, stakeholders, projects, based, identifying, processes, reports, sbs, creation, maintenance, directed, education, two, solve, problems, also, reporting, specific, responsibilities, include, time, independently'

# %%
# testing matching keywords between different jobs
match1 = len(set(dfp1_model.iloc[dfp1_model.index.get_loc('Data And Operations Analyst')]['Keywords']) & set(dfp1_model.iloc[dfp1_model.index.get_loc('Program Administrator')]['Keywords']))
print(match1)
# Out:
# 33

# %%
# Run this cell block first to determine accuracy
indices = pd.Series(dfp1_model.index)

def recommendations(title, csm=csm):
    
    recommended_jobs = []
    locations = []
    
    idx = indices[indices == title].index[0]
    score_series = pd.Series(csm[idx]).sort_values(ascending=False) 
    top15_indices = list(score_series.iloc[0:15].index)

    for i in top15_indices:
        recommended_jobs.append(list(dfp1_model.index)[i])
        locations.append(list(dfp1_model['Work Location'])[i])
        
    return recommended_jobs

# %% [markdown]
# ### Performance Evaluation

# %%
# performance evaluation will be based on averge number of matching keywords of recommended jobs and input job
from statistics import mean

def accuracy(title):
    matches = []
    for recmds in recommendations(title):
        matches.append(len(set(dfp1_model.iloc[dfp1_model.index.get_loc(recmds)]['Keywords']) & set(dfp1_model.iloc[dfp1_model.index.get_loc(title)]['Keywords'])))
        
    return (mean(matches)/max(matches))

# %%
accuracy('Data Analyst')
# Out:
# 0.9247863247863248

# %%
for title in dfp1_model.index:
    print(accuracy(title))
# Out:
# 0.8603174603174603
# 1.0
# 0.9481481481481482
# 1.0
# 0.9
# 0.9575757575757576
# 0.8882882882882883
# 0.9
# 0.9085714285714286
# 0.927927927927928
# 0.9447619047619048
# 0.8954954954954955
# 0.9254901960784313
# 0.9561904761904763
# 0.8540540540540541
# 0.9544715447154472
# 0.9230769230769231
# 0.9317073170731708
# 1.0
# 0.9675675675675675
# 0.8603174603174603
# 0.8747967479674796
# 0.8666666666666666
# 0.9561904761904763
# 0.9523809523809524
# 0.9621621621621622
# 0.9180952380952381
# 0.9365079365079365
# 0.888888888888889
# 0.9135135135135134
# 0.8957264957264957
# 0.8633333333333333
# 0.9352941176470588
# 0.968627450980392
# 0.9588235294117647
# 0.9296296296296297
# 0.9567567567567568
# 0.9759259259259259
# 0.9515151515151514
# 0.9629629629629629
# 0.9179487179487179
# 0.9024390243902439
# 0.9421052631578947
# 0.925
# 1.0
# 0.9099999999999999
# 0.9609195402298851
# 0.9950617283950618
# 0.9314814814814815
# 1.0
# 0.9722222222222222
# 0.9757575757575758
# 0.9555555555555555
# 0.972972972972973
# 0.905
# 0.95
# 0.9063492063492065
# 0.9368421052631579
# 0.9616666666666667
# 0.8333333333333334
# 0.9418803418803419
# 0.9059829059829061
# 0.9533333333333334
# 0.9447154471544715
# 0.9111111111111111
# 0.9747126436781609
# 0.9504761904761905
# 0.9658536585365854
# 0.9639639639639639
# 1.0
# 0.9183333333333333
# 1.0
# 0.9767441860465116
# 0.8861788617886179
# 0.9174603174603174
# 0.9837837837837837
# 1.0
# 0.8893939393939394
# 0.9318518518518518
# 0.9798449612403101
# 0.9301587301587302
# 0.9709401709401709
# 0.9827956989247312
# 0.9566666666666667
# 0.9316239316239316
# 0.9261261261261261
# 1.0
# 0.9416666666666667
# 0.9612403100775194
# 0.9521367521367521
# 0.9140350877192983
# 0.9739837398373983
# 1.0
# 0.9619047619047618
# 0.9369369369369369
# 0.9720430107526882
# 0.9289855072463769
# 0.96875
# 0.9723577235772358
# 1.0
# 0.9253968253968254
# 0.9833333333333333
# 0.9447154471544715
# 0.9748148148148148
# 0.9709401709401709
# 0.9525925925925927
# 1.0
# 0.925
# 0.9370370370370371
# 0.9604166666666667
# 0.9621621621621622
# 0.9572649572649573
# 0.8589147286821704
# 0.9523809523809524
# 0.893939393939394
# 0.9603603603603603
# 0.9733333333333334
# 0.9621621621621622
# 0.9282051282051282
# 0.93
# 0.9245614035087719
# 1.0
# 0.9621621621621622
# 0.93
# 0.9269841269841269
# 0.9233333333333332
# 0.9791666666666666
# 0.8837606837606838
# 0.9711711711711711
# 0.9500000000000001
# 0.9550000000000001
# 0.9450980392156862
# 0.9283333333333333
# 0.9414634146341464
# 1.0
# 1.0
# 0.9126984126984128
# 1.0
# 1.0
# 0.9825396825396825
# 0.9228070175438597
# 0.9073170731707317
# 1.0
# 1.0
# 0.8914728682170543
# 0.9199999999999999
# 0.9333333333333333
# 0.9454545454545454
# 1.0
# 0.9219047619047619
# 0.9199999999999999
# 1.0
# 0.8380952380952381
# 0.9315315315315316
# 0.915
# 0.8713178294573644
# 0.9585585585585586
# 0.9264957264957265
# 1.0
# 0.8957264957264957
# 0.8943089430894309
# 0.9214814814814816
# 0.8825396825396826
# 1.0
# 0.9585585585585586
# 0.9367521367521368
# 0.9024390243902439
# 0.9157894736842105
# 0.9485714285714286
# 0.8837209302325582
# 0.968627450980392
# 0.9333333333333332
# 1.0
# 1.0
# 0.9600000000000001
# 0.9529411764705882
# 0.8716666666666667
# 0.9711711711711711
# 0.9531531531531531
# 0.9407407407407408
# 0.910569105691057
# 1.0
# 0.9040650406504066
# 1.0
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.9042735042735043
# 0.8845528455284553
# 1.0
# 0.8636363636363636
# 0.9574074074074075
# 0.9433333333333334
# 0.9638095238095238
# 1.0
# 0.9675675675675675
# 0.9843137254901961
# 0.9720930232558139
# 0.9885057471264368
# 1.0
# 0.9504761904761905
# 0.9418803418803419
# 0.9434343434343434
# 0.9076923076923077
# 1.0
# 0.9264957264957265
# 0.9855855855855856
# 1.0
# 0.9666666666666667
# 0.9257142857142857
# 1.0
# 0.927927927927928
# 0.8868217054263566
# 0.9264957264957265
# 0.9437037037037037
# 0.9252032520325203
# 0.9647058823529411
# 0.9462962962962964
# 0.9315315315315316
# 0.9452991452991453
# 0.9521367521367521
# 0.9578947368421052
# 0.981981981981982
# 0.96875
# 0.919298245614035
# 0.958095238095238
# 0.8792792792792792
# 0.8803921568627451
# 0.9405405405405405
# 1.0
# 0.947008547008547
# 0.9407407407407408
# 0.95
# 0.9500000000000001
# 0.9285714285714286
# 0.889922480620155
# 0.9616666666666667
# 0.9516666666666668
# 0.8715447154471545

# %%
# Possible improvements/modifications
# changing all values to lowercase 
# remove all punctuations except comma
# removing all digits is likely to increase the performace of the model as it will simply match the keywords more precisely
# may be using all lower case letter will probably increase performace

# %% [markdown]
# ## Model Training with Deep Learning <a name='dtraining'></a>

# %%
# Combining columns into one
# ohe isn't possible for so many keywords
# splitting only the business title and job descrpition and minimum qual requirements columns
from pyspark.sql.functions import initcap

df_model = df_model.withColumn('Business Title', initcap('Business Title'))
df_model = df_model.withColumn('Job Description', initcap('Job Description'))
df_model = df_model.withColumn('Minimum Qual Requirements', initcap('Minimum Qual Requirements'))
df_model.show()
# Out:
# +------+--------------------+--------------------+-------------------------+--------------------+--------------------+
dfp2_model.head()
# Out:
#    Job ID                                     Business Title  \
# 0   87990                                    Account Manager
# 1   97899           Executive Director, Business Development
# 2  132292  Maintenance Worker - Technical Services-heatin...
# 3  132292  Maintenance Worker - Technical Services-heatin...
# 4  133921                                  Temporary Painter
#
#                                      Job Description  \
# 0  Division Of Economic & Financial Opportunity (...
# 1  The New York City Department Of Small Business...
# 2  Under Direct Supervision, Assist In The Routin...
# 3  Under Direct Supervision, Assist In The Routin...
# 4  Responsibilities Of Selected Candidates Will I...
#
#                            Minimum Qual Requirements  \
# 0  "1.\ta Baccalaureate Degree From An Accredited...
# 1  "1. A Baccalaureate Degree From An Accredited ...
# 2  "1. Three Years Of Full-time Satisfactory Expe...
# 3  "1. Three Years Of Full-time Satisfactory Expe...
# 4  1. Five Years Of Full-time Satisfactory Experi...
#
#                                     Preferred Skills  \
# 0   all candidates must have at least one year of...
# 1                                               None
# 2                                         mechanical
# 3                                         mechanical
# 4                                               None
#
#                   Work Location  \
# 0           110 William St. N Y
# 1           110 William St. N Y
# 2        Heating Mgt-Operations
# 3        Heating Mgt-Operations
# 4  DMP-Contract & Analysis Unit
#
#                                               Merged
# 0  Account Manager Division Of Economic & Financi...
# 1  Executive Director, Business Development The N...
# 2  Maintenance Worker - Technical Services-heatin...
# 3  Maintenance Worker - Technical Services-heatin...
# 4  Temporary Painter Responsibilities Of Selected...

# %%
dfp2_model['Merged'] = dfp2_model['Merged'].astype(str)

# %%
# removing all numbers and punctuation marks
import string
from string import digits

def remove_nums(text):
    for nums in digits:
        text = text.replace(nums, '')
    return text

def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# %%
dfp2_model['Merged'] = dfp2_model['Merged'].apply(remove_nums)
dfp2_model['Merged'] = dfp2_model['Merged'].apply(remove_punctuations)

# %%
dfp3_model = dfp2_model[['Business Title', 'Merged']]
dfp3_model.head()
# Out:
#                                       Business Title  \
# 0                                    Account Manager
# 1           Executive Director, Business Development
# 2  Maintenance Worker - Technical Services-heatin...
# 3  Maintenance Worker - Technical Services-heatin...
# 4                                  Temporary Painter
#
#                                               Merged
# 0  Account Manager Division Of Economic  Financia...
# 1  Executive Director Business Development The Ne...
# 2  Maintenance Worker  Technical Servicesheating ...
# 3  Maintenance Worker  Technical Servicesheating ...
# 4  Temporary Painter Responsibilities Of Selected...

# %%
# replace space with comma
dfp3_model['Merged'] = dfp3_model['Merged'].apply(lambda x: x.replace('  ', ', '))
dfp3_model.head()
# Out:
#                                       Business Title  \
# 0                                    Account Manager
# 1           Executive Director, Business Development
# 2  Maintenance Worker - Technical Services-heatin...
# 3  Maintenance Worker - Technical Services-heatin...
# 4                                  Temporary Painter
#
#                                               Merged
# 0  Account Manager Division Of Economic, Financia...
# 1  Executive Director Business Development The Ne...
# 2  Maintenance Worker, Technical Servicesheating ...
# 3  Maintenance Worker, Technical Servicesheating ...
# 4  Temporary Painter Responsibilities Of Selected...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.preprocessing.text import Tokenizer
from keras import metrics
# Out:
# Using TensorFlow backend.

# %%
# splitting data into training and testing sets
train, test = train_test_split(dfp3_model, test_size=0.2)   # random_state=200

trainTitle = train['Business Title']
trainMerge = train['Merged']

testTitle = train['Business Title']
testMerge = train['Merged']

# %%
numLabels = len(trainTitle.unique().tolist())
vocabSize = 1000
batchSize = 32
epochs = 20

tokenizer = Tokenizer(num_words=vocabSize)
tokenizer.fit_on_texts(trainMerge)

x_train = tokenizer.texts_to_matrix(trainMerge, mode='tfidf')
x_test = tokenizer.texts_to_matrix(testMerge, mode='tfidf')

encoder = LabelBinarizer()
encoder.fit(trainTitle)

y_train = encoder.transform(trainTitle)
y_test = encoder.transform(testTitle)

# %%
# define model
model = Sequential()
model.add(Dense(512, input_shape=(vocabSize, )))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(numLabels))
model.add(Activation('softmax'))

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=[metrics.categorical_accuracy, 'accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               512512
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1202)              616626
# _________________________________________________________________
# activation_2 (Activation)    (None, 1202)              0
# =================================================================
# Total params: 1,391,794
# Trainable params: 1,391,794
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, batch_size=batchSize, epochs=epochs, verbose=1, validation_split=0.1)
# Out:
# Epoch 1/20
# 73/73 [==============================] - 1s 12ms/step - loss: 7.1866 - categorical_accuracy: 0.0026 - accuracy: 0.0026 - val_loss: 7.0049 - val_categorical_accuracy: 0.0232 - val_accuracy: 0.0232
# Epoch 2/20
# 73/73 [==============================] - 1s 8ms/step - loss: 6.9666 - categorical_accuracy: 0.0215 - accuracy: 0.0215 - val_loss: 6.8453 - val_categorical_accuracy: 0.0541 - val_accuracy: 0.0541
# Epoch 3/20
# 73/73 [==============================] - 1s 7ms/step - loss: 6.7498 - categorical_accuracy: 0.0422 - accuracy: 0.0422 - val_loss: 6.6849 - val_categorical_accuracy: 0.0734 - val_accuracy: 0.0734
# Epoch 4/20
# 73/73 [==============================] - 1s 7ms/step - loss: 6.5313 - categorical_accuracy: 0.0542 - accuracy: 0.0542 - val_loss: 6.5478 - val_categorical_accuracy: 0.0772 - val_accuracy: 0.0772
# Epoch 5/20
# 73/73 [==============================] - 1s 15ms/step - loss: 6.3748 - categorical_accuracy: 0.0689 - accuracy: 0.0689 - val_loss: 6.4351 - val_categorical_accuracy: 0.0888 - val_accuracy: 0.0888
# Epoch 6/20
# 73/73 [==============================] - 1s 14ms/step - loss: 6.1797 - categorical_accuracy: 0.0865 - accuracy: 0.0865 - val_loss: 6.3137 - val_categorical_accuracy: 0.1197 - val_accuracy: 0.1197
# Epoch 7/20
# 73/73 [==============================] - 1s 9ms/step - loss: 5.9496 - categorical_accuracy: 0.1205 - accuracy: 0.1205 - val_loss: 6.2012 - val_categorical_accuracy: 0.1390 - val_accuracy: 0.1390
# Epoch 8/20
# 73/73 [==============================] - 1s 7ms/step - loss: 5.7885 - categorical_accuracy: 0.1373 - accuracy: 0.1373 - val_loss: 6.0957 - val_categorical_accuracy: 0.1467 - val_accuracy: 0.1467
# Epoch 9/20
# 73/73 [==============================] - 1s 7ms/step - loss: 5.5925 - categorical_accuracy: 0.1614 - accuracy: 0.1614 - val_loss: 5.9844 - val_categorical_accuracy: 0.1699 - val_accuracy: 0.1699
# Epoch 10/20
# 73/73 [==============================] - 1s 7ms/step - loss: 5.3943 - categorical_accuracy: 0.1873 - accuracy: 0.1873 - val_loss: 5.8736 - val_categorical_accuracy: 0.1815 - val_accuracy: 0.1815
# Epoch 11/20
# 73/73 [==============================] - 1s 11ms/step - loss: 5.1943 - categorical_accuracy: 0.2105 - accuracy: 0.2105 - val_loss: 5.7811 - val_categorical_accuracy: 0.1931 - val_accuracy: 0.1931
# Epoch 12/20
# 73/73 [==============================] - 1s 14ms/step - loss: 4.9786 - categorical_accuracy: 0.2411 - accuracy: 0.2411 - val_loss: 5.6792 - val_categorical_accuracy: 0.2008 - val_accuracy: 0.2008
# Epoch 13/20
# 73/73 [==============================] - 1s 14ms/step - loss: 4.7490 - categorical_accuracy: 0.2613 - accuracy: 0.2613 - val_loss: 5.5506 - val_categorical_accuracy: 0.2239 - val_accuracy: 0.2239
# Epoch 14/20
# 73/73 [==============================] - 1s 12ms/step - loss: 4.5668 - categorical_accuracy: 0.2988 - accuracy: 0.2988 - val_loss: 5.4504 - val_categorical_accuracy: 0.2201 - val_accuracy: 0.2201
# Epoch 15/20
# 73/73 [==============================] - 1s 8ms/step - loss: 4.3429 - categorical_accuracy: 0.3198 - accuracy: 0.3198 - val_loss: 5.3220 - val_categorical_accuracy: 0.2471 - val_accuracy: 0.2471
# Epoch 16/20
# 73/73 [==============================] - 1s 7ms/step - loss: 4.1319 - categorical_accuracy: 0.3638 - accuracy: 0.3638 - val_loss: 5.2157 - val_categorical_accuracy: 0.2664 - val_accuracy: 0.2664
# Epoch 17/20
# 73/73 [==============================] - 1s 7ms/step - loss: 3.9290 - categorical_accuracy: 0.3930 - accuracy: 0.3930 - val_loss: 5.1183 - val_categorical_accuracy: 0.2780 - val_accuracy: 0.2780
# Epoch 18/20
# 73/73 [==============================] - 1s 8ms/step - loss: 3.6789 - categorical_accuracy: 0.4296 - accuracy: 0.4296 - val_loss: 5.0105 - val_categorical_accuracy: 0.2741 - val_accuracy: 0.2741
# Epoch 19/20
# 73/73 [==============================] - 1s 14ms/step - loss: 3.4940 - categorical_accuracy: 0.4688 - accuracy: 0.4688 - val_loss: 4.8840 - val_categorical_accuracy: 0.2934 - val_accuracy: 0.2934
# Epoch 20/20
# 73/73 [==============================] - 1s 14ms/step - loss: 3.3259 - categorical_accuracy: 0.4864 - accuracy: 0.4864 - val_loss: 4.7840 - val_categorical_accuracy: 0.3166 - val_accuracy: 0.3166

# %%
# evaluation metrics
score = model.evaluate(x_test, y_test, batch_size=batchSize, verbose=1)
print('Test Accuracy: ', score[1])
print('Test Loss: ', score[0])
# Out:
# 81/81 [==============================] - 0s 6ms/step - loss: 2.7427 - categorical_accuracy: 0.6363 - accuracy: 0.6363
# Test Accuracy:  0.636328399181366
# Test Loss:  2.7426767349243164

# %%
# improving the model
from keras import optimizers
from keras.constraints import maxnorm

# %%
# splitting data into training and testing sets
train, test = train_test_split(dfp3_model, test_size=0.2)

trainTitle = train['Business Title']
trainMerge = train['Merged']

testTitle = train['Business Title']
testMerge = train['Merged']

# %%
numLabels = len(trainTitle.unique().tolist())
vocabSize = 1000
batchSize = 32
epochs = 50

tokenizer = Tokenizer(num_words=vocabSize)
tokenizer.fit_on_texts(trainMerge)

x_train = tokenizer.texts_to_matrix(trainMerge, mode='tfidf')
x_test = tokenizer.texts_to_matrix(testMerge, mode='tfidf')

encoder = LabelBinarizer()
encoder.fit(trainTitle)

y_train = encoder.transform(trainTitle)
y_test = encoder.transform(testTitle)

# %%
# define model again
model = Sequential()
model.add(Dense(4096, input_shape=(vocabSize, ), activation='relu', kernel_initializer='glorot_normal', kernel_constraint=maxnorm(2)))
model.add(Dropout(0.1))
model.add(Dense(1024, activation='relu', kernel_initializer='glorot_normal'))
model.add(Dropout(0.1))
model.add(Dense(numLabels))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=[metrics.categorical_accuracy, 'accuracy'])

# %%
report = model.fit(x_train, y_train, batch_size=batchSize, epochs=epochs, verbose=1, validation_split=0.1)
# Out:
# Epoch 1/50
# 73/73 [==============================] - 5s 73ms/step - loss: 6.9973 - categorical_accuracy: 0.0245 - accuracy: 0.0245 - val_loss: 6.7852 - val_categorical_accuracy: 0.0270 - val_accuracy: 0.0270
# Epoch 2/50
# 73/73 [==============================] - 5s 70ms/step - loss: 6.4525 - categorical_accuracy: 0.0697 - accuracy: 0.0697 - val_loss: 6.4793 - val_categorical_accuracy: 0.0656 - val_accuracy: 0.0656
# Epoch 3/50
# 73/73 [==============================] - 5s 69ms/step - loss: 5.9268 - categorical_accuracy: 0.1317 - accuracy: 0.1317 - val_loss: 6.1883 - val_categorical_accuracy: 0.1197 - val_accuracy: 0.1197
# Epoch 4/50
# 73/73 [==============================] - 5s 67ms/step - loss: 5.4057 - categorical_accuracy: 0.1941 - accuracy: 0.1941 - val_loss: 5.9097 - val_categorical_accuracy: 0.1853 - val_accuracy: 0.1853
# Epoch 5/50
# 73/73 [==============================] - 5s 68ms/step - loss: 4.8726 - categorical_accuracy: 0.2764 - accuracy: 0.2764 - val_loss: 5.6262 - val_categorical_accuracy: 0.2317 - val_accuracy: 0.2317
# Epoch 6/50
# 73/73 [==============================] - 5s 72ms/step - loss: 4.3488 - categorical_accuracy: 0.3797 - accuracy: 0.3797 - val_loss: 5.3702 - val_categorical_accuracy: 0.2857 - val_accuracy: 0.2857
# Epoch 7/50
# 73/73 [==============================] - 5s 73ms/step - loss: 3.8504 - categorical_accuracy: 0.4821 - accuracy: 0.4821 - val_loss: 5.1201 - val_categorical_accuracy: 0.2819 - val_accuracy: 0.2819
# Epoch 8/50
# 73/73 [==============================] - 5s 73ms/step - loss: 3.3819 - categorical_accuracy: 0.5669 - accuracy: 0.5669 - val_loss: 4.8927 - val_categorical_accuracy: 0.3282 - val_accuracy: 0.3282
# Epoch 9/50
# 73/73 [==============================] - 6s 82ms/step - loss: 2.9347 - categorical_accuracy: 0.6255 - accuracy: 0.6255 - val_loss: 4.6780 - val_categorical_accuracy: 0.3591 - val_accuracy: 0.3591
# Epoch 10/50
# 73/73 [==============================] - 5s 69ms/step - loss: 2.5583 - categorical_accuracy: 0.6840 - accuracy: 0.6840 - val_loss: 4.4385 - val_categorical_accuracy: 0.4170 - val_accuracy: 0.4170
# Epoch 11/50
# Epoch 40/50
# 73/73 [==============================] - 6s 87ms/step - loss: 0.1996 - categorical_accuracy: 0.9643 - accuracy: 0.9643 - val_loss: 3.1794 - val_categorical_accuracy: 0.7104 - val_accuracy: 0.7104
# Epoch 41/50
# 73/73 [==============================] - 5s 72ms/step - loss: 0.1909 - categorical_accuracy: 0.9660 - accuracy: 0.9660 - val_loss: 3.1884 - val_categorical_accuracy: 0.6988 - val_accuracy: 0.6988
# Epoch 42/50
# 73/73 [==============================] - 7s 89ms/step - loss: 0.1820 - categorical_accuracy: 0.9656 - accuracy: 0.9656 - val_loss: 3.1778 - val_categorical_accuracy: 0.7104 - val_accuracy: 0.7104
# Epoch 43/50
# 73/73 [==============================] - 7s 91ms/step - loss: 0.1812 - categorical_accuracy: 0.9630 - accuracy: 0.9630 - val_loss: 3.1827 - val_categorical_accuracy: 0.7066 - val_accuracy: 0.7066
# Epoch 44/50
# 73/73 [==============================] - 7s 92ms/step - loss: 0.1829 - categorical_accuracy: 0.9630 - accuracy: 0.9630 - val_loss: 3.1782 - val_categorical_accuracy: 0.7143 - val_accuracy: 0.7143
# Epoch 45/50
# 73/73 [==============================] - 5s 72ms/step - loss: 0.1782 - categorical_accuracy: 0.9621 - accuracy: 0.9621 - val_loss: 3.2131 - val_categorical_accuracy: 0.6988 - val_accuracy: 0.6988
# Epoch 46/50
# 73/73 [==============================] - 7s 91ms/step - loss: 0.1672 - categorical_accuracy: 0.9686 - accuracy: 0.9686 - val_loss: 3.1850 - val_categorical_accuracy: 0.7143 - val_accuracy: 0.7143
# Epoch 47/50
# 73/73 [==============================] - 7s 89ms/step - loss: 0.1616 - categorical_accuracy: 0.9660 - accuracy: 0.9660 - val_loss: 3.1884 - val_categorical_accuracy: 0.7104 - val_accuracy: 0.7104
# Epoch 48/50
# 73/73 [==============================] - 6s 87ms/step - loss: 0.1612 - categorical_accuracy: 0.9673 - accuracy: 0.9673 - val_loss: 3.1783 - val_categorical_accuracy: 0.7143 - val_accuracy: 0.7143
# Epoch 49/50
# 73/73 [==============================] - 5s 69ms/step - loss: 0.1545 - categorical_accuracy: 0.9712 - accuracy: 0.9712 - val_loss: 3.1969 - val_categorical_accuracy: 0.7027 - val_accuracy: 0.7027
# Epoch 50/50
# 73/73 [==============================] - 6s 88ms/step - loss: 0.1480 - categorical_accuracy: 0.9681 - accuracy: 0.9681 - val_loss: 3.1972 - val_categorical_accuracy: 0.6988 - val_accuracy: 0.6988

# %% [markdown]
# ## Results <a name='results'></a>

# %%
# evaluation metrics
score = model.evaluate(x_test, y_test, batch_size=batchSize, verbose=1)
print('Test Accuracy: ', score[1])
print('Test Loss: ', score[0])
# Out:
# 81/81 [==============================] - 1s 15ms/step - loss: 0.4208 - categorical_accuracy: 0.9516 - accuracy: 0.9516
# Test Accuracy:  0.9515879154205322
# Test Loss:  0.4208093583583832

# %%
model.save('Application/Job_Recommender.h5')

# %%
print(report.history.keys())
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'accuracy', 'val_loss', 'val_categorical_accuracy', 'val_accuracy'])

# %%
plt.plot(report.history['accuracy'])
plt.plot(report.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(report.history['loss'])
plt.plot(report.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
